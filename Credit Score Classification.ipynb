# %% [markdown]
# # Import  libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Import the dataset(train.csv)

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# # Check the head of the dataset

# %%
df.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %% [markdown]
# # Check the shape of the dataset

# %%
df.shape
# Out:
# (100000, 28)

# %% [markdown]
# # Check the number of rows and columns

# %%
print(f'Number of rows: {df.shape[0]}')
print(f'Number of columns: {df.shape[1]}')
# Out:
# Number of rows: 100000
# Number of columns: 28

# %% [markdown]
# # Check the info of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %% [markdown]
# # Check for NaN-Null values for each column

# %%
df.isnull().mean() * 100
# Out:
# ID                          0.0
# Customer_ID                 0.0
# Month                       0.0
# Name                        0.0
# Age                         0.0
# SSN                         0.0
# Occupation                  0.0
# Annual_Income               0.0
# Monthly_Inhand_Salary       0.0
# Num_Bank_Accounts           0.0
# Num_Credit_Card             0.0
# Interest_Rate               0.0
# Num_of_Loan                 0.0
# Type_of_Loan                0.0
# Delay_from_due_date         0.0
# Num_of_Delayed_Payment      0.0
# Changed_Credit_Limit        0.0
# Num_Credit_Inquiries        0.0
# Credit_Mix                  0.0
# Outstanding_Debt            0.0
# Credit_Utilization_Ratio    0.0
# Credit_History_Age          0.0
# Payment_of_Min_Amount       0.0
# Total_EMI_per_month         0.0
# Amount_invested_monthly     0.0
# Payment_Behaviour           0.0
# Monthly_Balance             0.0
# Credit_Score                0.0
# dtype: float64

# %% [markdown]
# # Create heatmap to see the correlation between the columns

# %%
plt.figure(figsize=(20, 10))
plt.title('Data Correlation')

dataplot = sns.heatmap(df.corr(numeric_only=True), cmap="YlGnBu", annot=True)

# %% [markdown]
# # Check the target column values(Credit Score)

# %%
df['Credit_Score'].value_counts()
# Out:
# Credit_Score
# Standard    53174
# Poor        28998
# Good        17828
# Name: count, dtype: int64

# %% [markdown]
# # Drop Credit_Mix column, because it has the same labels as the target column

# %%
df.drop('Credit_Mix', axis=1, inplace=True)

# %%
df
# Out:
#            ID  Customer_ID  Month           Name   Age          SSN  \
# 0        5634         3392      1  Aaron Maashoh  23.0  821000265.0
# 1        5635         3392      2  Aaron Maashoh  23.0  821000265.0
# 2        5636         3392      3  Aaron Maashoh  23.0  821000265.0
# 3        5637         3392      4  Aaron Maashoh  23.0  821000265.0
# 4        5638         3392      5  Aaron Maashoh  23.0  821000265.0
# ...       ...          ...    ...            ...   ...          ...
# 99995  155625        37932      4          Nicks  25.0   78735990.0
# 99996  155626        37932      5          Nicks  25.0   78735990.0
# 99997  155627        37932      6          Nicks  25.0   78735990.0
# 99998  155628        37932      7          Nicks  25.0   78735990.0
# 99999  155629        37932      8          Nicks  25.0   78735990.0
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0      Scientist       19114.12            1824.843333                3.0
# ...

# %% [markdown]
# # See the relation between Credit_Score(target column) and the Annual_Income

# %%
plt.figure(figsize=(12, 8))
plt.title('Credit Score Relation With Annual Income')

sns.barplot(data=df, x='Credit_Score', y='Annual_Income', hue='Credit_Score', )
# Out:
# <Axes: title={'center': 'Credit Score Relation With Annual Income'}, xlabel='Credit_Score', ylabel='Annual_Income'>

# %%
plt.figure(figsize=(20, 10))
# Set the labels for the axes
plt.xlabel('Occupation')
plt.ylabel('Count')

sns.histplot(data=df, x='Occupation', hue='Credit_Score', multiple='stack', shrink=0.8)
# Out:
# <Axes: xlabel='Occupation', ylabel='Count'>

# %% [markdown]
# # Drop Payment_Behavior column, because it does not include enough unique values

# %%
df.drop('Payment_Behaviour', axis=1, inplace=True)

# %% [markdown]
# # Also Payment_of_Min_Amount column

# %%
df.drop('Payment_of_Min_Amount', axis=1, inplace=True)

# %% [markdown]
#  # Drop ID columns ID, Customer_ID, because they are useful

# %%
df.drop(['ID', 'Customer_ID'], axis=1, inplace=True)

# %% [markdown]
# # Drop Month column

# %%
df.drop('Month', axis=1, inplace=True)

# %%
df
# Out:
#                 Name   Age          SSN Occupation  Annual_Income  \
# 0      Aaron Maashoh  23.0  821000265.0  Scientist       19114.12
# 1      Aaron Maashoh  23.0  821000265.0  Scientist       19114.12
# 2      Aaron Maashoh  23.0  821000265.0  Scientist       19114.12
# 3      Aaron Maashoh  23.0  821000265.0  Scientist       19114.12
# 4      Aaron Maashoh  23.0  821000265.0  Scientist       19114.12
# ...              ...   ...          ...        ...            ...
# 99995          Nicks  25.0   78735990.0   Mechanic       39628.99
# 99996          Nicks  25.0   78735990.0   Mechanic       39628.99
# 99997          Nicks  25.0   78735990.0   Mechanic       39628.99
# 99998          Nicks  25.0   78735990.0   Mechanic       39628.99
# 99999          Nicks  25.0   78735990.0   Mechanic       39628.99
#
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0                1824.843333                3.0              4.0
# ...

# %% [markdown]
# # Drop SSN column

# %%
df.drop('SSN', axis=1, inplace=True)

# %% [markdown]
# # Drop name column

# %%
df.drop('Name', axis=1, inplace=True)

# %%
df
# Out:
#         Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0      23.0  Scientist       19114.12            1824.843333
# 1      23.0  Scientist       19114.12            1824.843333
# 2      23.0  Scientist       19114.12            1824.843333
# 3      23.0  Scientist       19114.12            1824.843333
# 4      23.0  Scientist       19114.12            1824.843333
# ...     ...        ...            ...                    ...
# 99995  25.0   Mechanic       39628.99            3359.415833
# 99996  25.0   Mechanic       39628.99            3359.415833
# 99997  25.0   Mechanic       39628.99            3359.415833
# 99998  25.0   Mechanic       39628.99            3359.415833
# 99999  25.0   Mechanic       39628.99            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                    3.0              4.0            3.0          4.0
# 1                    3.0              4.0            3.0          4.0
# ...

# %% [markdown]
# # Convert target column (Credit_Score) to numerical values (0-Poor, 1-Standard, 2-Good)

# %%
df['Credit_Score'] = df['Credit_Score'].apply(lambda x: 0 if x == 'Poor' else 1 if x == 'Standard' else 2)

# %%
df['Credit_Score'].value_counts()
# Out:
# Credit_Score
# 1    53174
# 0    28998
# 2    17828
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Age                       100000 non-null  float64
#  1   Occupation                100000 non-null  object
#  2   Annual_Income             100000 non-null  float64
#  3   Monthly_Inhand_Salary     100000 non-null  float64
#  4   Num_Bank_Accounts         100000 non-null  float64
#  5   Num_Credit_Card           100000 non-null  float64
#  6   Interest_Rate             100000 non-null  float64
#  7   Num_of_Loan               100000 non-null  float64
#  8   Type_of_Loan              100000 non-null  object
#  9   Delay_from_due_date       100000 non-null  float64
#  10  Num_of_Delayed_Payment    100000 non-null  float64
#  11  Changed_Credit_Limit      100000 non-null  float64
#  12  Num_Credit_Inquiries      100000 non-null  float64
# ...

# %% [markdown]
# # Convert String column values to Numerical, using LabelEncoding

# %%
# import LabelEncoder class
from sklearn.preprocessing import LabelEncoder

# create an instance of LabelEncoder
le = LabelEncoder()

# transform our string columns
df['Occupation'] = le.fit_transform(df['Occupation'])
df['Type_of_Loan'] = le.fit_transform(df['Type_of_Loan'])

# %%
df
# Out:
#         Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0      23.0          12       19114.12            1824.843333
# 1      23.0          12       19114.12            1824.843333
# 2      23.0          12       19114.12            1824.843333
# 3      23.0          12       19114.12            1824.843333
# 4      23.0          12       19114.12            1824.843333
# ...     ...         ...            ...                    ...
# 99995  25.0           9       39628.99            3359.415833
# 99996  25.0           9       39628.99            3359.415833
# 99997  25.0           9       39628.99            3359.415833
# 99998  25.0           9       39628.99            3359.415833
# 99999  25.0           9       39628.99            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                    3.0              4.0            3.0          4.0
# 1                    3.0              4.0            3.0          4.0
# ...

# %% [markdown]
# # Train-Split our Dataset

# %%
# import train_split module
from sklearn.model_selection import train_test_split

# X will be used for training the ML model (not including the target column)
X = df.drop('Credit_Score', axis=1)

# target column
y = df['Credit_Score']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# # Scale the data (only the X values (X_train, X_test)

# %%
# import StandardScaler class
from sklearn.preprocessing import StandardScaler

# create an instance of StandardScaler
scaler = StandardScaler()

# scale the data
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Create ML model (KNN first)

# %%
# import KNN model
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# create an instance of KNN model
knn = KNeighborsClassifier(n_neighbors=5)  # number of K

# fit the model
knn.fit(X_train, y_train)

# model accuracy
y_pred = knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'KNN accuracy: {accuracy}')
# Out:
# KNN accuracy: 0.77285

# %% [markdown]
# # Metrics for KNN

# %%
# import metrics
from sklearn.metrics import f1_score, recall_score, precision_score

knn_recall = recall_score(y_test, y_pred, average='macro')
knn_precision = precision_score(y_test, y_pred, average='macro')
knn_f1 = f1_score(y_test, y_pred, average='macro')

print(f'KNN Recall: {knn_recall}')
print(f'KNN Precision: {knn_precision}')
print(f'KNN F1: {knn_f1}')
# Out:
# KNN Recall: 0.7572213075049553
# KNN Precision: 0.7607792894568114
# KNN F1: 0.758408732269249

# %% [markdown]
# # SVM model

# %%
# import SVM class
from sklearn.svm import SVC

# create an instance of SVM
svc = SVC()

# fit the model
svc.fit(X_train, y_train)

# predictions
y_pred = svc.predict(X_test)

# accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'SVM accuracy: {accuracy}')
# Out:
# SVM accuracy: 0.69505

# %% [markdown]
# # Metrics for SVM

# %%
# import metrics
from sklearn.metrics import f1_score, recall_score, precision_score

svm_recall = recall_score(y_test, y_pred, average='macro')
svm_precision = precision_score(y_test, y_pred, average='macro')
svm_f1 = f1_score(y_test, y_pred, average='macro')

print(f'SVM Recall: {svm_recall}')
print(f'SVM Precision: {svm_precision}')
print(f'SVM F1: {svm_f1}')
# Out:
# SVM Recall: 0.6358037234749133
# SVM Precision: 0.6882090618718634
# SVM F1: 0.6549998803635871

# %% [markdown]
# # Random Forest Model

# %%
# Import random forest model
from sklearn.ensemble import RandomForestClassifier

# create an instance of random forest classifier
rf = RandomForestClassifier()

# fit the model
rf.fit(X_train, y_train)

# predictions
y_pred = rf.predict(X_test)

# accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Random Forest accuracy: {accuracy}')
# Out:
# Random Forest accuracy: 0.8102

# %% [markdown]
# # Metrics for RF

# %%
# import metrics
from sklearn.metrics import f1_score, recall_score, precision_score

rf_recall = recall_score(y_test, y_pred, average='macro')
rf_precision = precision_score(y_test, y_pred, average='macro')
rf_f1 = f1_score(y_test, y_pred, average='macro')

print(f'RF Recall: {rf_recall}')
print(f'RF Precision: {rf_precision}')
print(f'RF F1: {rf_f1}')
# Out:
# RF Recall: 0.8037950979141857
# RF Precision: 0.8018929072288353
# RF F1: 0.8025900592930023

# %% [markdown]
# # Naive Bayes Model

# %%
# import NB model
from sklearn.naive_bayes import GaussianNB

# create an instance of NB
nb = GaussianNB()

# fit the model
nb.fit(X_train, y_train)

# predictions
y_pred = nb.predict(X_test)

# accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Naive Bayes accuracy: {accuracy}')
# Out:
# Naive Bayes accuracy: 0.59495

# %% [markdown]
# # metrics for NB

# %%
# import metrics
from sklearn.metrics import f1_score, recall_score, precision_score

nb_recall = recall_score(y_test, y_pred, average='macro')
nb_precision = precision_score(y_test, y_pred, average='macro')
nb_f1 = f1_score(y_test, y_pred, average='macro')

print(f'NB Recall: {nb_recall}')
print(f'NB Precision: {nb_precision}')
print(f'NB F1: {nb_f1}')
# Out:
# NB Recall: 0.657176881088257
# NB Precision: 0.6032776368867402
# NB F1: 0.5937911207922202
